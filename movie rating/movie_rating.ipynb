# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Load the Data

# %%
df = pd.read_csv("IMDb Movies India.csv",encoding='ISO-8859-1')
df.head(10)
# Out:
#                                  Name    Year Duration  \
# 0                                         NaN      NaN
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 2                         #Homecoming  (2021)   90 min
# 3                             #Yaaram  (2019)  110 min
# 4                   ...And Once Again  (2010)  105 min
# 5                ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                           ...Yahaan  (2005)  142 min
# 7                      .in for Motion  (2008)   59 min
# 8                  ?: A Question Mark  (2012)   82 min
# 9                            @Andheri  (2014)  116 min
#
#                        Genre  Rating  Votes            Director  \
# 0                      Drama     NaN    NaN       J.S. Randhawa
# 1                      Drama     7.0      8       Gaurav Bakshi
# 2             Drama, Musical     NaN    NaN  Soumyajit Majumdar
# 3            Comedy, Romance     4.4     35          Ovais Khan
# 4                      Drama     NaN    NaN        Amol Palekar
# 5     Comedy, Drama, Musical     4.7    827        Rahul Rawail
# 6        Drama, Romance, War     7.4  1,086      Shoojit Sircar
# 7                Documentary     NaN    NaN       Anirban Datta
# 8  Horror, Mystery, Thriller     5.6    326       Allyson Patel
# 9    Action, Crime, Thriller     4.0     11   Biju Bhaskar Nair
#
#            Actor 1                 Actor 2          Actor 3
# 0         Manmauji                  Birbal  Rajendra Bhatia
# 1     Rasika Dugal          Vivek Ghamande    Arvind Jangid
# 2     Sayani Gupta       Plabita Borthakur       Roy Angana
# 3          Prateik              Ishita Raj  Siddhant Kapoor
# 4     Rajat Kapoor      Rituparna Sengupta      Antara Mali
# 5       Bobby Deol  Aishwarya Rai Bachchan    Shammi Kapoor
# 6  Jimmy Sheirgill          Minissha Lamba   Yashpal Sharma
# 7              NaN                     NaN              NaN
# 8        Yash Dave          Muntazir Ahmad     Kiran Bhatia
# 9        Augustine            Fathima Babu             Byon

# %% [markdown]
# #### Preprocessing

# %%
df.shape
# Out:
# (15509, 10)

# %%
df.nunique()
# Out:
# Name        13838
# Year          102
# Duration      182
# Genre         485
# Rating         84
# Votes        2034
# Director     5938
# Actor 1      4718
# Actor 2      4891
# Actor 3      4820
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  object
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.2+ MB

# %%
df.describe()
# Out:
#             Rating
# count  7919.000000
# mean      5.841621
# std       1.381777
# min       1.100000
# 25%       4.900000
# 50%       6.000000
# 75%       6.800000
# max      10.000000

# %%
# check for nan values
df.isna().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
df.dropna(subset=['Name','Year','Duration','Rating','Votes'],axis=0,inplace=True)
df
# Out:
#                                      Name    Year Duration  \
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 3                                 #Yaaram  (2019)  110 min
# 5                    ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                               ...Yahaan  (2005)  142 min
# 8                      ?: A Question Mark  (2012)   82 min
# ...                                   ...     ...      ...
# 15493                              Zubaan  (2015)  115 min
# 15494                            Zubeidaa  (2001)  153 min
# 15503                     Zulm Ki Zanjeer  (1989)  125 min
# 15505                               Zulmi  (1999)  129 min
# 15508                        Zulm-O-Sitam  (1998)  130 min
#
#                            Genre  Rating  Votes         Director  \
# 1                          Drama     7.0      8    Gaurav Bakshi
# 3                Comedy, Romance     4.4     35       Ovais Khan
# 5         Comedy, Drama, Musical     4.7    827     Rahul Rawail
# 6            Drama, Romance, War     7.4  1,086   Shoojit Sircar
# 8      Horror, Mystery, Thriller     5.6    326    Allyson Patel
# ...                          ...     ...    ...              ...
# 15493                      Drama     6.1    408      Mozez Singh
# 15494  Biography, Drama, History     6.2  1,496    Shyam Benegal
# 15503       Action, Crime, Drama     5.8     44  S.P. Muthuraman
# 15505              Action, Drama     4.5    655       Kuku Kohli
# 15508              Action, Drama     6.2     20     K.C. Bokadia
#
#                Actor 1                 Actor 2           Actor 3
# 1         Rasika Dugal          Vivek Ghamande     Arvind Jangid
# 3              Prateik              Ishita Raj   Siddhant Kapoor
# 5           Bobby Deol  Aishwarya Rai Bachchan     Shammi Kapoor
# 6      Jimmy Sheirgill          Minissha Lamba    Yashpal Sharma
# 8            Yash Dave          Muntazir Ahmad      Kiran Bhatia
# ...                ...                     ...               ...
# 15493    Vicky Kaushal         Sarah Jane Dias  Raaghavv Chanana
# 15494   Karisma Kapoor                   Rekha    Manoj Bajpayee
# 15503      Chiranjeevi              Jayamalini       Rajinikanth
# 15505     Akshay Kumar          Twinkle Khanna       Aruna Irani
# 15508       Dharmendra              Jaya Prada       Arjun Sarja
#
# [5851 rows x 10 columns]

# %% [markdown]
# #### Data Cleaning

# %%
# For year change given format into number
df['Year'] = df['Year'].str.strip('()').astype(int)

# %%
# For votes change format into one singlenumber
df['Votes'] = df['Votes'].str.replace(',','').astype(int)

# for Duration remove min and make as number
df['Duration'] = df['Duration'].str.replace('min','').astype(int)

# %%
df.describe()
# Out:
#               Year     Duration       Rating          Votes
# count  5851.000000  5851.000000  5851.000000    5851.000000
# mean   1996.416852   132.294480     5.931875    2611.273116
# std      19.914640    26.555826     1.389942   13433.828528
# min    1931.000000    21.000000     1.100000       5.000000
# 25%    1983.000000   117.000000     5.000000      28.000000
# 50%    2002.000000   134.000000     6.100000     119.000000
# 75%    2013.000000   150.000000     7.000000     862.500000
# max    2021.000000   321.000000    10.000000  591417.000000

# %%
df.dropna(subset=['Year'], inplace=True)
df.dropna(subset=['Genre'], inplace=True)
df['Rating'].fillna(df['Rating'].mode().max(), inplace=True)
df['Duration'].fillna(df['Duration'].mean(), inplace=True)
df['Votes'].fillna(df['Votes'].mean(), inplace=True)
df.dropna(subset=['Director', 'Actor 1', 'Actor 2', 'Actor 3', 'Genre'], inplace=True)

# %%
df.isna().sum()
# Out:
# Name        0
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# dtype: int64

# %% [markdown]
# ##### Data Visualization

# %%
numeric_columns = df.select_dtypes(include=['number']).columns
plt.figure(figsize=(12, 8))

for i, column in enumerate(numeric_columns, 1):
    plt.subplot(2, 2, i)
    plt.hist(df[column], bins=10, color='skyblue', edgecolor='black',density=True, alpha=0.7)
    df[column].plot.kde(color='red', linestyle='dashed')
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
categorical_columns = ['Director', 'Actor 1', 'Actor 2', 'Actor 3']

plt.figure(figsize=(12, 10))

for i, column in enumerate(categorical_columns, 1):
    plt.subplot(2, 2, i)
    sns.countplot(x=column, data=df, palette='viridis')
    plt.title(f'Count Plot of {column}')
    plt.xlabel(column)
    plt.ylabel('Count')

plt.tight_layout()      ###Prevents overlapping
plt.show()

# %%
df.hist(figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'Year'}>,
#         <AxesSubplot:title={'center':'Duration'}>],
#        [<AxesSubplot:title={'center':'Rating'}>,
#         <AxesSubplot:title={'center':'Votes'}>]], dtype=object)

# %%
Q1 = df['Rating'].quantile(0.25)
Q3 = df['Rating'].quantile(0.75)
IQR = Q3 - Q1

lb = Q1 - 1.5 * IQR
ub = Q3 + 1.5 * IQR

outliers = df[(df['Rating'] < lb) | (df['Rating'] > ub)]

plt.figure(figsize=(8, 6))
sns.scatterplot(x=outliers.index, y=outliers['Rating'], color='green', label='Outliers')
plt.title('Boxplot with Outliers')
plt.show()

outliers
# Out:
#                                           Name  Year  Duration  \
# 1473                               B.A. Pass 2  2017       125
# 1488                                  Baaghi 3  2020       143
# 2918                     Chatur Singh Two Star  2011       150
# 3618                                Desh Drohi  2008       140
# 4170                              Dracula 2012  2013       137
# 5114                              Glamour Girl  2000       123
# 5523          Hari Puttar: A Comedy of Terrors  2008        90
# 5711                                Himmatwala  2013       150
# 5915   Humein Tumse Pyar Ho Gaya Chupke Chupke  2003       135
# 5933                                Humshakals  2014       159
# 6346                                   Jackpot  2013       132
# 6826                  Joy: The Real Love Story  2007       127
# 7362                                   Karzzzz  2008       142
# 7958                      Kyaa Kool Hain Hum 3  2016       124
# 8339                           Love Qubool Hai  2020        94
# 9639                   Mumbai Can Dance Saalaa  2015       135
# 11005                               Prem Aggan  1998       168
# 11041                               Prem Qaidi  1991       156
# 11454                                   Race 3  2018       160
# 11463                                    Radhe  2021       135
# 11644                   Ram Gopal Varma Ki Aag  2007       171
# 12171                                  Sadak 2  2020       133
# 13593                              Super Model  2013        83
# 13907                            Tera Intezaar  2017       108
# 14155                      The Legend of Drona  2008       138
# 14356                            Time to Dance  2021       113
# 15040                      Welcome to New York  2018       118
#
#                             Genre  Rating   Votes             Director  \
# 1473                        Drama     2.1     419          Shadab Khan
# 1488      Action, Comedy, Musical     2.1   10309           Ahmed Khan
# 2918    Action, Adventure, Comedy     1.7     624        Ajay Chandhok
# 3618             Action, Thriller     1.4    3899    Jagdish A. Sharma
# 4170                       Horror     1.9     128              Vinayan
# 5114                        Crime     2.1      23          Rakesh Bedi
# 5523        Comedy, Drama, Family     1.9     314         Rajesh Bajaj
# 5711        Action, Comedy, Drama     1.7    8186           Sajid Khan
# 5915                        Drama     1.7      27       Pramod Mandloi
# 5933       Comedy, Drama, Romance     1.8    7840           Sajid Khan
# 6346             Comedy, Thriller     2.0     721        Kaizad Gustad
# 6826     Drama, Romance, Thriller     2.1    1619      Prashant Chadha
# 7362       Action, Drama, Musical     2.1    1238       Satish Kaushik
# 7958                       Comedy     1.9    4165         Umesh Ghadge
# 8339               Drama, Romance    10.0       5      Saif Ali Sayeed
# 9639                        Drama     1.6      43     Sachindra Sharma
# 11005              Drama, Romance     1.7     544           Feroz Khan
# 11041             Action, Romance     2.1     153  K. Muralimohana Rao
# 11454     Action, Crime, Thriller     1.9   42457         Remo D'Souza
# 11463     Action, Crime, Thriller     1.8  162455          Prabhu Deva
# 11644   Action, Adventure, Comedy     1.7    6655      Ram Gopal Varma
# 12171               Action, Drama     1.1   67785         Mahesh Bhatt
# 13593     Drama, Mystery, Romance     1.9     180          Navin Batra
# 13907           Romance, Thriller     1.8     262        Raajeev Walia
# 14155  Action, Adventure, Fantasy     2.0    2442          Goldie Behl
# 14356            Musical, Romance     1.8     730      Stanley D'Costa
# 15040               Comedy, Drama     1.6     774        Chakri Toleti
#
#                         Actor 1             Actor 2                  Actor 3
# 1473                Shadab Khan    Kritika Sachdeva  Satiiysh Saarathy Sasho
# 1488               Tiger Shroff    Riteish Deshmukh          Shraddha Kapoor
# 2918                Sanjay Dutt       Ameesha Patel              Anupam Kher
# 3618          Kamal Rashid Khan         Gracy Singh          Hrishitaa Bhatt
# 4170                   Thilakan        Shraddha Das             Monal Gajjar
# 5114   Kishore Anand Bhanushali        Dolly Bindra          Poonam Dasgupta
# 5523                Lucky Kohli       Jackie Shroff                   Sarika
# 5711                 Ajay Devgn    Tamannaah Bhatia         Mahesh Manjrekar
# 5915               Meghna Desai    Siddharth Dhawan            Dinesh Hingoo
# 5933              Saif Ali Khan    Riteish Deshmukh               Ram Kapoor
# 6346           Naseeruddin Shah         Sunny Leone            Sachiin Joshi
# 6826          Himesh Reshammiya     Hansika Motwani         Mallika Sherawat
# 7362          Himesh Reshammiya    Urmila Matondkar             Shweta Kumar
# 7958             Tusshar Kapoor    Aftab Shivdasani         Krishna Abhishek
# 8339                  Ahaan Jha      Mahesh Narayan      Rajasree Rajakumari
# 9639              Shakti Kapoor  Prashant Narayanan          Aditya Pancholi
# 11005              Fardeen Khan      Meghna Kothari          Sameer Malhotra
# 11041            Karisma Kapoor              Harish            Shafi Inamdar
# 11454               Anil Kapoor         Salman Khan               Bobby Deol
# 11463               Salman Khan        Disha Patani            Randeep Hooda
# 11644          Amitabh Bachchan            Mohanlal               Ajay Devgn
# 12171                Alia Bhatt       Priyanka Bose              Sanjay Dutt
# 13593              Ashmit Patel         Veena Malik              Sana Oberoi
# 13907               Arbaaz Khan         Sunny Leone              Bhani Singh
# 14155            Jayshree Arora           Veer Arya        Abhishek Bachchan
# 14356           Sooraj Pancholi       Isabelle Kaif        Waluscha De Sousa
# 15040            Richard Harris        Jasmine Kaur           Sonakshi Sinha

# %% [markdown]
# #### Correlation Matrix

# %%
columns = ['Votes', 'Rating', 'Duration', 'Year']

correlation = df[columns].corr()
plt.figure(figsize=(10,5))
sns.heatmap(correlation,annot=True,xticklabels=columns,yticklabels=columns,fmt='.2f',linewidths=0.05,cmap='viridis')
plt.show()

# %%
df.head(2)
# Out:
#                                  Name  Year  Duration            Genre  \
# 1  #Gadhvi (He thought he was Gandhi)  2019       109            Drama
# 3                             #Yaaram  2019       110  Comedy, Romance
#
#    Rating  Votes       Director       Actor 1         Actor 2          Actor 3
# 1     7.0      8  Gaurav Bakshi  Rasika Dugal  Vivek Ghamande    Arvind Jangid
# 3     4.4     35     Ovais Khan       Prateik      Ishita Raj  Siddhant Kapoor

# %% [markdown]
# #### Feature Engineering

# %%
#### REMOVE UNRELATED COLUMNS

df.drop(['Name','Genre','Director','Actor 1','Actor 2','Actor 3'],axis=1,inplace=True)
df.head(5)
# Out:
#    Year  Duration  Rating  Votes
# 1  2019       109     7.0      8
# 3  2019       110     4.4     35
# 5  1997       147     4.7    827
# 6  2005       142     7.4   1086
# 8  2012        82     5.6    326

# %%
df.columns
# Out:
# Index(['Year', 'Duration', 'Rating', 'Votes'], dtype='object')

# %% [markdown]
# ##### Split the data

# %%
x = df.drop('Rating',axis=1)
y = df['Rating']

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

rf_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('random', RandomForestRegressor(random_state=42))
])

rf_pipeline.fit(x_train, y_train)
y_pred_rf = rf_pipeline.predict(x_test)

# %%
mse_rf = mean_squared_error(y_test, y_pred_rf)
print(f'Random Forest Mean Squared Error: {mse_rf}')
mae_rf = mean_absolute_error(y_test,y_pred_rf)
print(f'Random Forest Mean Absolute Error: {mse_rf}')
r2_rf = r2_score(y_test,y_pred_rf)
print(f'Random Forest R2-score: {mse_rf}')
# Out:
# Random Forest Mean Squared Error: 1.4911385523203768
# Random Forest Mean Absolute Error: 1.4911385523203768
# Random Forest R2-score: 1.4911385523203768

# %%
rf_pipeline.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('random', RandomForestRegressor(random_state=42))])

# %%
y_pred = rf_pipeline.predict(x_test)

# %%
user_input = {}
for feature in x_train.columns:
    user_input[feature] = float(input(f"Enter the value for {feature}: "))

# Create a DataFrame from the user input
user_df = pd.DataFrame([user_input])

predict = rf_pipeline.predict(user_df)

# Convert array to a normal value representation
predict = predict[0]

predict
# Out:
# Enter the value for Year: 2017
# Enter the value for Duration: 125
# Enter the value for Votes: 419
# 2.7259999999999973

# %% [markdown]
# ##### A pipeline in machine learning is a sequence of data processing steps that are chained together to streamline the workflow. It is a way to organize and automate the machine learning process, ensuring that data preprocessing, model training, and any other necessary steps are executed in a consistent and reproducible manner. Pipelines are useful for improving code readability, preventing data leakage, and facilitating tasks like hyperparameter tuning and model deployment. They contribute to the efficiency, maintainability, and reproducibility of machine learning workflows.

# %% [markdown]
# #### EX:
# ##### .Enter the value for Year: 2017
# ##### .Enter the value for Duration: 125
# ##### .Enter the value for Votes: 419
# ##### 2.7259999999999973
